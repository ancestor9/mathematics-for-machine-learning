# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/mathematics-for-machine-learning/blob/main/scripts/LA_linear_transformation_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Original Image**

# %%
import requests
from PIL import Image
from io import BytesIO

# URL of the image
image_url = "https://people.com/thmb/h67yba4NaGbpnv9DZVZm894kSjo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():focal(979x292:981x294)/Brad-Pitt_1-2000-e8a294b80b034e659785ad813d3f02f2.jpg"

# Send a GET request to the URL
response = requests.get(image_url)

# Check if the request was successful (status code 200)
print(response.status_code)
# Out:
# 200

# %%
# Open the image using PIL
image = Image.open(BytesIO(response.content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1000>

# %%
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# ### **[NumPy: the absolute basics for beginners](https://numpy.org/doc/2.2/user/absolute_beginners.html)**

# %%
import numpy as np
image_array = np.array(image)
image_array
# Out:
# array([[[215, 214, 228],
#         [215, 214, 228],
#         [215, 214, 228],
#         ...,
#         [165, 181, 207],
#         [165, 181, 207],
#         [165, 181, 207]],
#
#        [[215, 214, 228],
#         [215, 214, 228],
#         [215, 214, 228],
#         ...,
#         [163, 179, 205],
#         [163, 179, 205],
#         [163, 179, 205]],
#
#        [[215, 214, 228],
#         [215, 214, 228],
#         [215, 214, 228],
#         ...,
#         [163, 179, 205],
#         [163, 179, 205],
#         [163, 179, 205]],
#
#        ...,
#
#        [[187, 195, 216],
#         [185, 196, 216],
#         [188, 196, 217],
#         ...,
#         [122, 154, 193],
#         [122, 154, 193],
#         [122, 154, 193]],
#
#        [[180, 191, 213],
#         [179, 191, 213],
#         [181, 192, 214],
#         ...,
#         [122, 154, 193],
#         [123, 155, 194],
#         [122, 154, 193]],
#
#        [[169, 181, 203],
#         [169, 181, 203],
#         [170, 182, 204],
# ...

# %%
image_array.shape
# Out:
# (1000, 1500, 3)

# %% [markdown]
# ## **1. Gray Image**

# %%
import numpy as np
image_array = np.array(image)
img = image_array[:,:,0]
img
# Out:
# array([[215, 215, 215, ..., 165, 165, 165],
#        [215, 215, 215, ..., 163, 163, 163],
#        [215, 215, 215, ..., 163, 163, 163],
#        ...,
#        [187, 185, 188, ..., 122, 122, 122],
#        [180, 179, 181, ..., 122, 123, 122],
#        [169, 169, 170, ..., 125, 125, 124]], dtype=uint8)

# %%
img.shape
# Out:
# (1000, 1500)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %% [markdown]
# # **Practice**
# - [scipy.misc.face](https://docs.scipy.org/doc/scipy-1.13.1/reference/generated/scipy.misc.face.html) 에서 라쿤이미지를 다운받아 R, G, B로 각각 시각화하라
# - [NumPy 100 Exercises (실습 위주)- 자습하기](https://github.com/rougier/numpy-100/blob/master/100_Numpy_exercises.ipynb)

# %% [markdown]
# ## **2. Sheer Matrix(Sheer Function)**
# - Linear Transformation

# %%
sheer_matrix = np.array([[1,10], [0,1]])
sheer_matrix
# Out:
# array([[ 1, 10],
#        [ 0,  1]])

# %%
# Define the shear factor (adjust as needed)
shear_factor = 1.2

# Create a shear matrix for horizontal shear
shear_matrix = (1, shear_factor, 0, 0, 1, 0)

# Apply the shear transformation to the image
sheared_image = image.transform(image.size, Image.AFFINE, shear_matrix, Image.BICUBIC)

# %%
sheared_image
# Out:
# <PIL.Image.Image image mode=RGB size=1500x1000>

# %% [markdown]
# ## **Kernel Function**

# %%
from sklearn.datasets import make_circles
X, y = make_circles(n_samples=500, random_state=11, noise=0.1)
plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap='coolwarm');

# %%
# Kernel Function

z =np.exp(-(X ** 2).sum(1))

# %%
from mpl_toolkits import mplot3d

plt.figure(figsize=(8,6))
ax = plt.axes(projection='3d')
ax.scatter3D(X[:, 0], X[:, 1], z, c=y, cmap='coolwarm')
#ax.view_init(10, 250)
